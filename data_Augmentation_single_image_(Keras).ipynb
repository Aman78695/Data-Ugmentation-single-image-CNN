# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman78695/Data-Ugmentation-single-image-CNN/blob/main/data_Augmentation_single_image_(Keras).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tensorflow as tf
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# %%
img=tf.keras.utils.load_img('/content/silver-tabby-cat-sitting-on-green-background-free-photo.jpg',target_size=(200,200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4299B90E20>

# %%
datagen=ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2

     
)

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
# convert image into array
from tensorflow.keras.utils import img_to_array

# %%
img=img_to_array(img)

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
input_batch=img.reshape(1,200,200,3)

# %%
i=0
for output in datagen.flow(input_batch,batch_size=1,
save_to_dir='preview', save_prefix='cat', save_format='jpeg'):
  i=i+1
  if i==10:
    break
